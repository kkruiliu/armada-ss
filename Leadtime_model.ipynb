# %% [markdown]
# <a href="https://colab.research.google.com/github/kkruiliu/armada-ss/blob/main/Leadtime_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Placeholder for the CSV file name
csv_file_path = '/content/Understanding Data - SS_PO_FACT.csv' # You can change this to your actual file path

try:
    # Read the CSV file into a pandas DataFrame
    df = pd.read_csv(csv_file_path)

    print(f"Successfully loaded '{csv_file_path}'")

    # Get the shape of the DataFrame (number of rows, number of columns)
    print("\nDataFrame Shape:")
    print(df.shape)

    # Display the first 5 rows of the DataFrame
    print("\nFirst 5 rows of the DataFrame:")
    print(df.head())

    # Display basic information about the DataFrame (column names, non-null counts, data types)
    print("\nDataFrame Info:")
    df.info()

    # Display descriptive statistics for numerical columns
    print("\nDescriptive Statistics:")
    print(df.describe())

except FileNotFoundError:
    print(f"Error: The file '{csv_file_path}' was not found. Please ensure the path is correct.")
except pd.errors.EmptyDataError:
    print(f"Error: The file '{csv_file_path}' is empty.")
except pd.errors.ParserError:
    print(f"Error: Could not parse the file '{csv_file_path}'. Check if it's a valid CSV.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Successfully loaded '/content/Understanding Data - SS_PO_FACT.csv'
#
# DataFrame Shape:
# (110222, 58)
#
# First 5 rows of the DataFrame:
#    PONUMBER  ITEMBRANCHSKEY  CARRIERID ITEMIDTRIM  SHIPTTOLOCATIONCODE  \
# 0  49453568          539047      25401      93620                  492
# 1  49453568          536496      25401      78354                  492
# 2  49453568          561060      25401      94610                  492
# 3  49453568          539493      25401      93667                  492
# 4  49453568          546380      25401      94396                  492
#
#    SUPPLIERID                        SUPPLIERNAME  TOTALLEADTIME  \
# 0       27977  Custom Foods - Knoxville, Pleasant             22
# 1       27977  Custom Foods - Knoxville, Pleasant             21
# 2       27977  Custom Foods - Knoxville, Pleasant             21
# 3       27977  Custom Foods - Knoxville, Pleasant             22
# 4       27977  Custom Foods - Knoxville, Pleasant             21
#
# ...

# %% [markdown]
# Raw Data
#
# 1. Outliers -> +/- 1.5 IQR
#
# 2. Missing values /inconsistencies -> KNN-imputation/avg
#
# 3. Understand the data types -> categorical, nominal, numeric, etc -> potential encoding? (optional)
#
# 4. Correlation analysis -> features vs target -> feature within
#
# 5. Scaling (if needed) -> standard scaling or min-max scaling if needed depending on the model
#
# 6. Train - test - val   split. 80-20 train test, 80-> 70-10 train val (hyperparameters)
#
# 7. Decision tree regressor, GBRegressor, XGBRegressor, KNNRegressor, Polynomial Refression, Neural Netork(MLP) (optional), time-series model
#
# 8. Gridsearch or hyperparameter
#
# 9. Metrics
